# %%
import numpy as np

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread('C:\Users\user\Pictures\Saved Pictures\distorsi.jpg')
plt.imshow(img)
# Out:
#   File "<ipython-input-5-ec391dfb482a>", line 1
#     img = mpimg.imread('C:\Users\user\Pictures\Saved Pictures\distorsi.jpg')
#                       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
img = mpimg.imread(r'C:\Users\user\Pictures\Saved Pictures\distorsi.jpg')
plt.imshow(img)

# %%
objp = np.zeros((6*7,3), np.float32)
objp[:,:2] = np.mgrid[0:7,0:6].T.reshape(-1,2)

# %%
objpoints = [] # 3d point in real world space
imgpoints = [] # 2d points in image plane

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
rer, corners = cv2.findChessboardCorners(gray, (8,6), None)

# %%
if ret == True:
    imgpoints.append(corners)
    objpoints.append(objp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-0ce892624e46> in <module>
# ----> 1 if ret == True:
#       2     imgpoints.append(corners)
#       3     objpoints.append(objp)
#
# NameError: name 'ret' is not defined

# %%
if rer == True:
    imgpoints.append(corners)
    objpoints.append(objp)

# %%
img = cv2.drawChessboardCorners(img, (8,6), corners, rer)
plt.imshow(img)
